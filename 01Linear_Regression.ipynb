# %% [markdown]
# <a href="https://colab.research.google.com/github/sumitgaurav25/python---practice/blob/main/01Linear_Regression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn import linear_model

# %%
df = pd.read_csv("/Homeprices.csv")
df
# Out:
#    area   price
# 0  2600  550000
# 1  3000  565000
# 2  3200  610000
# 3  3600  680000
# 4  4000  725000

# %%
# %matplotlib inline
plt.xlabel("Area (sq ft.)")
plt.ylabel("Price ($)")
plt.scatter(df.area,df.price, color = "red", marker = "+")

# %%
#create a object for linear regression
reg = linear_model.LinearRegression()

#fit my data or training the linear regression model acc to given data
reg.fit(df[['area']], df.price)
# Out:
# LinearRegression()

# %%
reg.predict([[3300]])
# Out:
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([628715.75342466])

# %%
reg.predict([[5000]])
# Out:
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([859554.79452055])

# %%
d = pd.read_csv("/areas.csv")
d
# Out:
#    area
# 0  1000
# 1  1500
# 2  2875
# 3  2500
# 4  2400
# 5  2425
# 6  2670
# 7  8670

# %%
prices = reg.predict(d[['area']])

d['prices'] = prices

d.to_csv("/prediction.csv")

# %%
# %matplotlib inline
plt.xlabel("Area (sq ft.)")
plt.ylabel("Price ($)")
plt.scatter(df.area,df.price, color = "red", marker = "+")
plt.plot(df.area, reg.predict(df[['area']]))
