# %% [markdown]
# <a href="https://colab.research.google.com/github/sumitgaurav25/python---practice/blob/main/06logisticRegression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn import linear_model

# %%
df = pd.read_csv("insurance_data.csv")
df
# Out:
#     age  bought_insurance
# 0    22                 0
# 1    25                 0
# 2    47                 1
# 3    52                 0
# 4    46                 1
# 5    56                 1
# 6    55                 0
# 7    60                 1
# 8    62                 1
# 9    61                 1
# 10   18                 0
# 11   28                 0
# 12   27                 0
# 13   29                 0
# 14   49                 1
# 15   55                 1
# 16   25                 1
# 17   58                 1
# 18   19                 0
# 19   18                 0
# 20   21                 0
# 21   26                 0
# 22   40                 1
# 23   45                 1
# 24   50                 1
# 25   54                 1
# 26   23                 0

# %%
plt.scatter(df['age'], df['bought_insurance'],marker='+', color='red')

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, Y_train, Y_test = train_test_split(df[['age']], df['bought_insurance'], test_size = 0.2)

# %%
X_test
# Out:
#     age
# 8    62
# 18   19
# 1    25
# 13   29
# 11   28
# 20   21

# %%
X_train.shape
# Out:
# (21, 1)

# %%
Y_train.shape
# Out:
# (21,)

# %%
print(X_train.shape, Y_train.shape)
# Out:
# (21, 1) (21,)

# %%
from sklearn.linear_model import LogisticRegression

reg = LogisticRegression()

reg.fit(X_train, Y_train)
# Out:
# LogisticRegression()

# %%
reg.predict(X_test)
# Out:
# array([1, 0, 0, 0, 0, 0])

# %%
reg.score(X_train, Y_train)
# Out:
# 1.0
